# %%
# 파이썬의 import를 활용해 데이터 분석용 패키지인 판다스(Pandas)를 읽어옵니다.
import pandas as pd

# 판다스 데이터프레임(DataFrame)을 출력할 때, 최대 출력할 수 있는 컬럼을 100개로 늘려줍니다.
# 이렇게 해야 데이터를 분석할 때 출력해서 확인하기 편합니다.
pd.options.display.max_columns = 100

# %%
raw_log = pd.read_csv("data/BA06_현시점 안전내구성능평가 및 단기성능공사계획 조사.csv",encoding='CP949')

# %%
print(raw_log.columns)
print(raw_log.shape)
raw_log.head(5)
# Out:
# Index(['No.', '시설물 명칭', '시설물 일련번호', '공사명', '공사 대상 부재(또는 시설물)',
#        '설계 예상시작일(yyyymmdd)', '설계 예상종료일(yyyymmdd)', '공사 예상 시작일(yyyymmdd)',
#        '공사 예상종료일(yyyymmdd)', '공사금액(백만원)', '첨부자료(설계도면, 설계내역서, 공정표 등)', '비고'],
#       dtype='object')
# (1107, 12)
#    No.       시설물 명칭     시설물 일련번호             공사명          공사 대상 부재(또는 시설물)  \
# 0    1  7145 뚝섬유원지역  BA060000228  조류유입 방지시설 설치공사  고가 기둥(P1, P8, P19)주변 개구부
# 1    2   2-091 신설동역  BA060000054          화장실 확충             화장실 및 장애인 화장실
# 2    3    2-094 신답역  BA060000055          화장실 확충             화장실 및 장애인 화장실
# 3    4    2-095 용답역  BA060000056          화장실 확충             화장실 및 장애인 화장실
# 4    5   3-015 무악재역  BA060000067          화장실 확충             화장실 및 장애인 화장실
#
#   설계 예상시작일(yyyymmdd) 설계 예상종료일(yyyymmdd)  공사 예상 시작일(yyyymmdd)  \
# 0                NaN                NaN             20200102
# 1                NaN                NaN             20200102
# 2                NaN                NaN             20200102
# 3                NaN                NaN             20200102
# 4                NaN                NaN             20200102
#
#    공사 예상종료일(yyyymmdd)  공사금액(백만원)  첨부자료(설계도면, 설계내역서, 공정표 등)  비고
# 0            20201231   47300000                       NaN NaN
# 1            20201231  556600000                       NaN NaN
# 2            20201231  556600000                       NaN NaN
# 3            20201231  556600000                       NaN NaN
# 4            20201231  556600000                       NaN NaN

# %%
raw_log.sort_index(by = "공사금액(백만원)")
# Out:
# C:\Users\APROS-1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   """Entry point for launching an IPython kernel.
#        No.               시설물 명칭     시설물 일련번호                  공사명  \
# 553    554           6130 광흥창역사  BA060000185  환기구 관리 표지판(통일시안) 설치
# 487    488           4-055 남태령역  BA060000119  환기구 관리 표지판(통일시안) 설치
# 486    487         4-053 사당역(4)  BA060000118  환기구 관리 표지판(통일시안) 설치
# 485    486         4-051 총신대입구역  BA060000117  환기구 관리 표지판(통일시안) 설치
# 484    485            4-048 동작역  BA060000116  환기구 관리 표지판(통일시안) 설치
# 483    484            4-046 이촌역  BA060000115  환기구 관리 표지판(통일시안) 설치
# 482    483           4-044 신용산역  BA060000114  환기구 관리 표지판(통일시안) 설치
# 481    482           4-042 삼각지역  BA060000113  환기구 관리 표지판(통일시안) 설치
# 480    481          4-040 숙대입구역  BA060000112  환기구 관리 표지판(통일시안) 설치
# 479    480         4-038 서울역(4)  BA060000111  환기구 관리 표지판(통일시안) 설치
# 478    479            4-036 회현역  BA060000110  환기구 관리 표지판(통일시안) 설치
# 477    478            4-034 명동역  BA060000109  환기구 관리 표지판(통일시안) 설치
# 476    477           4-032 충무로역  BA060000108  환기구 관리 표지판(통일시안) 설치
# 475    476  4-030 동대문역사문화공원역(4)  BA060000107  환기구 관리 표지판(통일시안) 설치
# 474    475        4-028 동대문역(4)  BA060000106  환기구 관리 표지판(통일시안) 설치
# 473    474            4-026 혜화역  BA060000105  환기구 관리 표지판(통일시안) 설치
# 472    473         4-024 한성대입구역  BA060000104  환기구 관리 표지판(통일시안) 설치
# 471    472        4-022 성신여대입구역  BA060000103  환기구 관리 표지판(통일시안) 설치
# 470    471            4-020 길음역  BA060000102  환기구 관리 표지판(통일시안) 설치
# 469    470         4-018 미아사거리역  BA060000101  환기구 관리 표지판(통일시안) 설치
# 468    469            4-016 미아역  BA060000100  환기구 관리 표지판(통일시안) 설치
# 467    468            4-014 수유역  BA060000099  환기구 관리 표지판(통일시안) 설치
# 466    467            4-012 쌍문역  BA060000097  환기구 관리 표지판(통일시안) 설치
# 465    466            4-008 창동역  BA060000098  환기구 관리 표지판(통일시안) 설치
# 464    465            4-006 노원역  BA060000096  환기구 관리 표지판(통일시안) 설치
# 463    464            4-004 상계역  BA060000095  환기구 관리 표지판(통일시안) 설치
# 462    463           4-002 당고개역  BA060000094  환기구 관리 표지판(통일시안) 설치
# 461    462            3-070 오금역  BA060000093  환기구 관리 표지판(통일시안) 설치
# 488    489            5102 방화역사  BA060000120  환기구 관리 표지판(통일시안) 설치
# 460    461          3-068 경찰병원역  BA060000092  환기구 관리 표지판(통일시안) 설치
# ...    ...                  ...          ...                  ...
# 1104  1105            7114 노원역사  BA060000213         승강편의시설 설치 출자
# 368    369           7107 도봉산역사  BA060000210            승강장 지붕 개량
# 1102  1103            6110 구산역사  BA060000175         승강편의시설 설치 출자
# 926    927         4-053 사당역(4)  BA060000118         승강편의시설 설치 출자
# 925    926            4-014 수유역  BA060000099         승강편의시설 설치 출자
# 923    924           3-005 구파발역  BA060000062         승강편의시설 설치 출자
# 921    922         2-056 서울대입구역  BA060000038         승강편의시설 설치 출자
# 924    925            3-035 옥수역  BA060000076         승강편의시설 설치 출자
# 922    923            2-060 신림역  BA060000040         승강편의시설 설치 출자
# 1100  1101            7124 먹골역사  BA060000218         승강편의시설 설치 출자
# 935    936            4-012 쌍문역  BA060000097         승강편의시설 설치 출자
# 933    934           4-002 당고개역  BA060000094         승강편의시설 설치 출자
# 934    935            4-004 상계역  BA060000095         승강편의시설 설치 출자
# 6        7             4-11 노원역  BA060000096     승강장 지붕 개량(채광판 등)
# 1103  1104            5112 발산역사  BA060000125         승강편의시설 설치 출자
# 1106  1107          7170 장승배기역사  BA060000240         승강편의시설 설치 출자
# 1105  1106            7116 중계역사  BA060000214         승강편의시설 설치 출자
# 1098  1099            7138 군자역사  BA060000225         승강편의시설 설치 출자
# 938    939         7182 가산디지털단지  BA060000246      역사 출입구 및 캐노피 개선
# 126    127         2-001 시청역(2)  BA060000011           공기질 개선(석면)
# 203    204          2-030 잠실나루역  BA060000025            지상역사 리모델링
# 202    203            2-027 강변역  BA060000024            지상역사 리모델링
# 208    209         4-038 서울역(4)  BA060000111           역사시설(냉방)개선
# 207    208         4-024 한성대입구역  BA060000104           역사시설(냉방)개선
# 206    207            4-012 쌍문역  BA060000097           역사시설(냉방)개선
# 201    202            2-021 성수역  BA060000021            지상역사 리모델링
# 209    210         3-047 남부터미널역  BA060000082           역사시설(냉방)개선
# 205    206            4-016 미아역  BA060000100           역사시설(냉방)개선
# 204    205     2-034 잠실새내역(신천역)  BA060000027           역사시설(냉방)개선
# 210    211           3-019 경복궁역  BA060000069           역사시설(냉방)개선
#
#      공사 대상 부재(또는 시설물) 설계 예상시작일(yyyymmdd) 설계 예상종료일(yyyymmdd)  \
# 553        환기구 관리 표지판                NaN                NaN
# 487        환기구 관리 표지판                NaN                NaN
# 486        환기구 관리 표지판                NaN                NaN
# 485        환기구 관리 표지판                NaN                NaN
# 484        환기구 관리 표지판                NaN                NaN
# 483        환기구 관리 표지판                NaN                NaN
# 482        환기구 관리 표지판                NaN                NaN
# 481        환기구 관리 표지판                NaN                NaN
# 480        환기구 관리 표지판                NaN                NaN
# 479        환기구 관리 표지판                NaN                NaN
# 478        환기구 관리 표지판                NaN                NaN
# 477        환기구 관리 표지판                NaN                NaN
# 476        환기구 관리 표지판                NaN                NaN
# 475        환기구 관리 표지판                NaN                NaN
# 474        환기구 관리 표지판                NaN                NaN
# 473        환기구 관리 표지판                NaN                NaN
# 472        환기구 관리 표지판                NaN                NaN
# 471        환기구 관리 표지판                NaN                NaN
# 470        환기구 관리 표지판                NaN                NaN
# 469        환기구 관리 표지판                NaN                NaN
# 468        환기구 관리 표지판                NaN                NaN
# 467        환기구 관리 표지판                NaN                NaN
# 466        환기구 관리 표지판                NaN                NaN
# 465        환기구 관리 표지판                NaN                NaN
# 464        환기구 관리 표지판                NaN                NaN
# 463        환기구 관리 표지판                NaN                NaN
# 462        환기구 관리 표지판                NaN                NaN
# 461        환기구 관리 표지판                NaN                NaN
# 488        환기구 관리 표지판                NaN                NaN
# 460        환기구 관리 표지판                NaN                NaN
# ...               ...                ...                ...
# 1104           승강편의시설                NaN                NaN
# 368            승강장 지붕                NaN                NaN
# 1102           승강편의시설                NaN                NaN
# 926            승강편의시설                NaN                NaN
# 925            승강편의시설                NaN                NaN
# 923            승강편의시설                NaN                NaN
# 921            승강편의시설                NaN                NaN
# 924            승강편의시설                NaN                NaN
# 922            승강편의시설                NaN                NaN
# 1100           승강편의시설                NaN                NaN
# 935            승강편의시설                NaN                NaN
# 933            승강편의시설                NaN                NaN
# 485                        NaN NaN
# 484                        NaN NaN
# 483                        NaN NaN
# 482                        NaN NaN
# 481                        NaN NaN
# 480                        NaN NaN
# 479                        NaN NaN
# 478                        NaN NaN
# 477                        NaN NaN
# 476                        NaN NaN
# 475                        NaN NaN
# 474                        NaN NaN
# 473                        NaN NaN
# 472                        NaN NaN
# 471                        NaN NaN
# 470                        NaN NaN
# 469                        NaN NaN
# 468                        NaN NaN
# 467                        NaN NaN
# 466                        NaN NaN
# 465                        NaN NaN
# 464                        NaN NaN
# 463                        NaN NaN
# 462                        NaN NaN
# 461                        NaN NaN
# 488                        NaN NaN
# 460                        NaN NaN
# ...                        ...  ..
# 1104                       NaN NaN
# 368                        NaN NaN
# 1102                       NaN NaN
# 926                        NaN NaN
# 925                        NaN NaN
# 923                        NaN NaN
# 921                        NaN NaN
# 924                        NaN NaN
# 922                        NaN NaN
# 1100                       NaN NaN
# 935                        NaN NaN
# 933                        NaN NaN
# 934                        NaN NaN
# 6                          NaN NaN
# 1103                       NaN NaN
# 1106                       NaN NaN
# 1105                       NaN NaN
# 1098                       NaN NaN
# 938                        NaN NaN
# 126                        NaN NaN
# 203                        NaN NaN
# 202                        NaN NaN
# 208                        NaN NaN
# 207                        NaN NaN
# 206                        NaN NaN
# 201                        NaN NaN
# 209                        NaN NaN
# 205                        NaN NaN
# 204                        NaN NaN
# 210                        NaN NaN
#
# [1107 rows x 12 columns]

# %%
raw_log[["공사금액(백만원)"]].sort_values(by="공사금액(백만원)")
# Out:
#         공사금액(백만원)
# 553        280000
# 487        280000
# 486        280000
# 485        280000
# 484        280000
# 483        280000
# 482        280000
# 481        280000
# 480        280000
# 479        280000
# 478        280000
# 477        280000
# 476        280000
# 475        280000
# 474        280000
# 473        280000
# 472        280000
# 471        280000
# 470        280000
# 469        280000
# 468        280000
# 467        280000
# 466        280000
# 465        280000
# 464        280000
# 463        280000
# 462        280000
# 461        280000
# 488        280000
# 460        280000
# ...           ...
# 1104   1138000000
# 368    1250000000
# 1102   1450000000
# 926    1496000000
# 925    1496000000
# 923    1496000000
# 921    1496000000
# 924    1496000000
# 922    1576000000
# 1100   1624800000
# 935    1666000000
# 933    1667000000
# 934    1667000000
# 6      1939000000
# 1103   2175000000
# 1106   2264000000
# 1105   2264000000
# 1098   3888800000
# 938    4636000000
# 126   12965000000
# 203   13703000000
# 202   14850000000
# 208   26694000000
# 207   26694000000
# 206   26694000000
# 201   29400000000
# 209   31681000000
# 205   58889000000
# 204   58889000000
# 210   67260000000
#
# [1107 rows x 1 columns]

# %%
# 평균값이 아닌 값을 구하고 싶을때는 aggfunc를 사용 
pd.pivot_table(raw_log, index = "시설물 명칭",values = "공사금액(백만원)", aggfunc=['sum','max'])
# Out:
#                           sum          max
#                     공사금액(백만원)    공사금액(백만원)
# 시설물 명칭
# 1-002 서울역            37340000     27690000
# 1-004 시청역            37340000     27690000
# 2-001 시청역(2)       27590000
# 2-003 을지로입구역       27590000
# 2-005 을지로3가역       27590000
# 2-007 을지로4가역       27590000
# 2-009 동대문역사문화공원역   27590000
# 2-011 신당역          27590000
# 2-013 상왕십리역        27590000
# 2-015 왕십리역         27590000
# 2-017 한양대역         27590000
# 2-019 뚝섬역          27590000
# 2-021 성수역          27590000
# 2-023 건대입구역        27590000
# 2-025 구의역          27590000
# 2-027 강변역          27590000
# 2-030 잠실나루역        27590000
# 2-032 잠실역          27590000
# 2-034 잠실새내역(신천역)   27590000
# 2-036 종합운동장역       27590000
# 2-038 삼성역          27590000
# 2-040 선릉역          27590000
# ...                     ...
# 7184 철산역사           1650000
# 7186 광명사거리역사        1650000
# 7188 천왕역사           1650000
# 7194 온수역사           1650000
# 7197 까치울역사          1650000
# 7199 부천종합운동장역사      1650000
# 7201 춘의역사           1650000
# 7203 신중동역사          1650000
# 7205 부천시청역사         1650000
# 7207 상동역사           1650000
# 7209 삼산체육관역사        1650000
# 7211 굴포천역사          1650000
# 7213 부평구청역사         1650000
# 8102 암사역사           1650000
# 8104 천호역사           1650000
# 8106 강동구청역사         1650000
# 8108 몽촌토성역사         1650000
# 8110 잠실역사           1650000
# 8112 석촌역사           1650000
# 8114 송파역사           1650000
# 8116 가락시장역사         1650000
# 8118 문정역사           1650000
# 8120 장지역사           1650000
# 8122 복정역사           1650000
# 8126 산성역사           1650000
# 8128 남한산성입구역사       1650000
# 8130 단대오거리역사        1650000
# 8132 신흥역사           1650000
# 8134 수진역사           1650000
# 8136 모란역사           1650000
#
# [279 rows x 1 columns]

# %%
raw_log["공사금액(백만원)"].mean()   # 평균금액 .mean()
# Out:
# 392488889.79223126

# %%
raw_log["공사금액(백만원)"].astype({'공사금액(백만원)':'float'}).dtypes
# Out:
# dtype('float64')

# %%
raw_log["공사금액(백만원)"].sum()   # 평균금액 .mean()
# Out:
# 434485201000

# %%
total=0 
temp = raw_log["공사금액(백만원)"]
temp1 = raw_log["시설물 명칭"]
#temp = raw_log["공사금액(백만원)"] 

money_columns = ['2호선공사 총 금액']

log = log[money_columns]


def total_money(temp1):
    
      #  for i in range(1106):
        
                if temp1[1][0] == "2":
                    log["2호선공사 총 금액"] += temp[i]
                    return


                else:
                    return 0


raw_log["호선별 시설물 총 금액"] = raw_log["시설물 명칭"].apply(total_money)
raw_log["호선별 시설물 총 금액"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\APROS-1\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2호선공사 총 금액'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-cca4d1dfa640> in <module>
#      17
#      18
# ---> 19 raw_log["호선별 시설물 총 금액"] = raw_log["시설물 명칭"].apply(total_money)
#      20 raw_log["호선별 시설물 총 금액"]
#
# C:\Users\APROS-1\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-49-cca4d1dfa640> in total_money(temp1)
#       9
#      10                 if temp1[1][0] == "2":
# ---> 11                     raw_log["2호선공사 총 금액"] += temp[i]
#      12                     return
#      13
#
# C:\Users\APROS-1\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\Users\APROS-1\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2호선공사 총 금액'
